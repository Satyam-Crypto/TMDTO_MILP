# %%
def keystream(B,S):
    L = B[7] + B[11] + B[30] + B[40] + B[45] + B[54] + B[71]
    Q = B[4]*B[21] + B[9]*B[52] + B[18]*B[37] + B[44]*B[76]
    T = B[5] + B[8]*B[82] + B[34]*B[67]*B[73] + B[2]*B[28]*B[41]*B[65] + B[13]*B[29]*B[50]*B[64]*B[75] \
    + B[6]*B[14]*B[26]*B[32]*B[47]*B[61] + B[1]*B[19]*B[27]*B[43]*B[57]*B[66]*B[78]
    T_c = S[23] + S[3]*S[16] + S[9]*S[13]*B[48] + S[1]*S[24]*B[38]*B[63]
    
    out = L + Q + T + T_c
    return out

def NFSR1_bk_update(S):
    temp = S[30]  + S[1]  +  S[4]  + S[5]  +  S[14] + S[16] + S[17] + S[19] +  S[24] + S[7]*S[17] + S[7]*S[19] + S[11]*S[20] \
        + S[13]*S[18] + S[16]*S[20] + S[19]*S[21] + S[3]*S[11]*S[21] + S[3]*S[18]*S[21] + S[6]*S[19]*S[20] \
        + S[7]*S[17]*S[21] + S[7]*S[19]*S[21] + S[11]*S[18]*S[21] + S[19]*S[20]*S[21] + S[3]*S[6]*S[11]*S[20]\
        + S[3]*S[6]*S[18]*S[20] + S[3]*S[11]*S[20]*S[21] + S[3]*S[18]*S[20]*S[21] + S[6]*S[7]*S[17]*S[20] \
        + S[6]*S[7]*S[19]*S[20] + S[6]*S[11]*S[18]*S[20] + S[7]*S[17]*S[20]*S[21] + S[7]*S[19]*S[20]*S[21]\
        + S[11]*S[18]*S[20]*S[21]
    
    S = [temp] + S[:30]
    return S

def NFSR2_bk_update(B,s0):
    temp = s0 + B[89] + B[23] + B[48] + B[78] + B[83] + B[2]*B[58] + B[9]*B[11] + B[14]*B[15] + B[24]*B[52] \
    + B[34]*B[41] + B[54]*B[57] + B[59]*B[73] + B[19]*B[21]*B[22] + B[61]*B[67]*B[71] \
    + B[76]*B[79]*B[80]*B[82]
    
    B = [temp] + B[:89]
    return B
    
def NFSR1_fw_update(S):
    temp = S[0]  + S[2]  +  S[5]  + S[6]  +  S[15] + S[17] + S[18] + S[20] +  S[25] + S[8]*S[18] + S[8]*S[20] + S[12]*S[21] \
        + S[14]*S[19] + S[17]*S[21] + S[20]*S[22] + S[4]*S[12]*S[22] + S[4]*S[19]*S[22] + S[7]*S[20]*S[21] \
        + S[8]*S[18]*S[22] + S[8]*S[20]*S[22] + S[12]*S[19]*S[22] + S[20]*S[21]*S[22] + S[4]*S[7]*S[12]*S[21]\
        + S[4]*S[7]*S[19]*S[21] + S[4]*S[12]*S[21]*S[22] + S[4]*S[19]*S[21]*S[22] + S[7]*S[8]*S[18]*S[21] \
        + S[7]*S[8]*S[20]*S[21] + S[7]*S[12]*S[19]*S[21] + S[8]*S[18]*S[21]*S[22] + S[8]*S[20]*S[21]*S[22]\
        + S[12]*S[19]*S[21]*S[22]
    
    for i in range(30):
        S[i]=S[i + 1]
    S[30]=temp
    return(S)

    
def NFSR2_fw_update(B,s0):
    temp = s0 + B[0] + B[24] + B[49] + B[79] + B[84] + B[3]*B[59] + B[10]*B[12] + B[15]*B[16] + B[25]*B[53] \
    + B[35]*B[42] + B[55]*B[58] + B[60]*B[74] + B[20]*B[22]*B[23] + B[62]*B[68]*B[72] \
    + B[77]*B[80]*B[81]*B[83]
    
    for i in range(89):
        B[i]=B[i + 1]
    B[89]=temp
    return(B)


def intersection(A,B):
    temp = []
    for i in range(len(A)):
        if A[i] in B:
            temp.append(A[i])
    return temp

# %%
filename = 'Lizard_TMDTO_fwd.txt'
csv_file = 'Lizard_TMDTO_fwd.csv'
for keys in range(1,23,1):
    import time
    start2 = time.time()

    state_len = 121
    V = BooleanPolynomialRing(state_len,['b%d'%(i) for i in range(90)] + ['s%d'%(i) for i in range(31)])
    #V.inject_variables()
    g = list(V.gens()) 

    #Assigning variables to the registers
    B = g[:90] 
    S = g[90:]
    
    
    #R = [90+i for i in range(23,31,1)] + [92] +\
    #[i for i in range(63,70,1)]
#
    #F = [i for i in range(34,46,1)] + [i for i in range(72,82,1)]
#
    #G = [i for i in range(state_len) if i not in R+F]
    R = []
    F = []
    G = []
    for i in F:
        if i < 90:
            B[i] = 0
        else:
            S[i-90] = 0


    linear = []
    linear_all = []
    n1 = 0
    Z = [0]*keys

    for loop in range(keys):
        Z[loop] = keystream(B,S)
        monom = list(Z[loop].monomials())
        lin = []
        for i in monom:
            if i.degree() > 1:
                n1 += 1
            if i.degree() == 1 and g.index(i) not in linear_all:
                lin = lin + [g.index(i)]
        linear.append(lin)
        linear_all = linear_all + lin
        print("loop 1st part ",loop)
        if loop != keys-1:
            B=NFSR2_fw_update(B,S[0])
            S=NFSR1_fw_update(S) 
    print("1st part done")

    #Assigning variables to the registers
    B = g[:90] 
    S = g[90:]

    for i in F:
        if i < 90:
            B[i] = 0
        else:
            S[i-90] = 0



    import gurobipy as gp
    from gurobipy import GRB
    import numpy as np
    model = gp.Model()


    v = [0,1,2]             # Temporary variable to be used for gurobi variable definition
    aux = [i for i in range(n1)]

    #Let D, F, G represents the class of determined/recovery, Fixed bit, and Guess bit
    #Since these are set and we need variables to denote R,F and G therefore let 2=R, 3=F and 4=G
    #x represents variables for each register and m contains 3 variables for each x[i] i.e. for R,F and G
    x = model.addVars(len(B) + len(S), lb = 2, ub = 4, vtype = GRB.INTEGER, name = "x")
    m = model.addVars(len(B) + len(S), len(v), vtype = GRB.BINARY, name = "m")
    q = model.addVars(len(aux), vtype = GRB.BINARY, name = "q")
    #p = model.addVars(len(aux), vtype = GRB.BINARY, name = "p")
    #r = model.addVars(len(aux), vtype = GRB.BINARY, name = "r")
    model.update()

    model.addConstrs((m[i,0] == 1) for i in R)
    model.addConstrs((m[i,1] == 1) for i in F)
    model.addConstrs((m[i,2] == 1) for i in G)

    #Objective function is to maximize recovery bit and minimize the number of FIXED bit
    model.setObjectiveN(gp.quicksum((m[i,0]) for i in range(state_len)),0,1, GRB.MAXIMIZE)
    model.setObjectiveN(gp.quicksum((m[i,1]) for i in range(state_len)),1,0, GRB.MINIMIZE)
    #model.setObjectiveN(gp.quicksum((m[i,1]) for i in range(state_len)), GRB.MINIMIZE)
    
    
    model.addConstrs((x[i] == (2*m[i,0] + 3*m[i,1] + 4*m[i,2])) for i in range(state_len))
    model.addConstrs(m[i,0] + m[i,1] + m[i,2] == 1 for i in range(state_len))

    #Number of recovered bit should be less than or equal to the number of keystream equations
    #model.addConstr(gp.quicksum(m[i,0] for i in range(state_len)) == keys)
    model.addConstr(gp.quicksum(m[i,0] for i in range(state_len) if i not in linear_all) == 0)

    count = 0
    cnt = 0
    for loop in range(keys):
        z = Z[loop]
        #z_var contains the index of variables in Z
        #z_var = np.array(z.variables())
        #z_var = [g.index(i) for i in z_var]
        z_monom = np.array(z.monomials())

        z_linear = [g.index(i) for i in z_monom if i.degree() == 1]

        #z_nlinear = [list(i.variables()) for i in z_monom if len(i.variables()) > 1]
        #z_nlinear = [g.index(z_nlinear[i][j]) for i in range(len(z_nlinear)) for j in range(len(z_nlinear[i]))]
        #z_nlinear = list(set(z_nlinear))


        #linear_new = [i for i in z_linear if i not in (linear + z_nlinear)]
        #z_linear_org = [i for i in z_linear if i not in z_nlinear]


        #One of the linear term variables which is not in the previous linear term has one recovered bit
        model.addConstr(gp.quicksum(m[i,0] for i in linear[loop]) <= 1)    
        #model.addConstr(gp.quicksum(m[i,0] for i in z_linear) <= loop + 1) 



        for mon in z_monom:
            if mon.degree() > 1:
                var = list(mon.variables())
                var = [g.index(i) for i in var]
                inters = [0]*len(linear)
                n = [0]*len(linear)
                for l in range(len(linear)):
                    inters[l] = intersection(var,linear[l])
                    n[l] = len(inters[l])

                C_prev = [n[i] for i in range(loop)] 
                C_current = [n[loop]]
                C_future = [n[i] for i in range(loop+1,keys,1)]

                #Case 1: recovered var in mon and is in linear
                #if sum(C_prev) > 0 and sum(C_current) == 0 and sum(C_future) == 0 :
                #    #if recovery found then guess
                #    model.addConstr((p[count] == 0) >> (gp.quicksum(m[i,0] for i in var) == 0))
                #    model.addConstr((p[count] == 1) >> (gp.quicksum((m[i,1] + m[i,2]) for i in var) >= len(var) - sum(C_prev)))
                #    count += 1

                #Case 2: recovered var in mon and is in z_linear-linear
                if (sum(C_current + C_future) > 0):
                    #if recovery found then fix to zero
                    prev = []
                    for k in range(loop):
                        prev = prev + inters[k]
                    #var_ge = [i for i in var if i not in prev]

                    var_ge = []
                    for k in range(loop,len(linear),1):
                        var_ge = var_ge + inters[k]


                    model.addConstr((q[count] == 0) >> (gp.quicksum(m[i,0] for i in var_ge) == 0))
                    model.addConstr((q[count] == 1) >> (gp.quicksum(m[i,1] for i in var) >= 1))
                    count += 1

                #if (sum(C_prev + C_current + C_future) == 0): 
                #    model.addConstr(gp.quicksum((m[i,0]) for i in var) == 0)
        print("2nd part loop ", loop)
    print("2nd part done")
    import time

    model.params.outputflag = 0
    start = time.time()
    model.optimize()
    end = time.time() - start
   

    print("Keystream = ",keys)
    print("status",model.STATUS)
    
    f = open(filename,'a')
    f.write("\nKeystream = " + str(keys))
    f.write("\nStatus " + str(model.STATUS) + "\n")
    
    if model.STATUS == 2:
        val = model.x
        R = []
        F = []
        G = []
        for i in range(state_len):
            if round(val[i]) == 2:
                R.append(i)
            if round(val[i]) == 3:
                F.append(i)
            if round(val[i]) == 4:
                G.append(i)



        Rec = [g[i] for i in R]
        Fix = [g[i] for i in F]
        Guess = [g[i] for i in G]
        print("Recovery Bit ",Rec)
        print("Fixed Bit ",Fix)
        print("Guessed Bit ",Guess)
        
        f.write(str("Recovery Bit ") + str(Rec) + "\n")
        f.write(str("Fixed Bit ") + str(Fix) + "\n")
        f.write(str("Guessed Bit ") + str(Guess) + "\n")
        
        
        print(len(R),len(F))
        if (len(R) + len(F) + len(G) == state_len) and len(intersection(R,F) + intersection(F,G) + intersection(R,G)) == 0:
            print("Length verified")
            f.write("\nLength Verified\n\n")
    end2 = time.time()-start2
    print("Gurobi Time = ", end)
    print("Overall Time = ", end2)
    
    f.write("\n\nGurobi Time = " + str(end))
    f.write("\nOverall Time = " + str(end2))
    f.close()


    #keys = len(R)
    B = [g[i] for i in range(90)]
    S = [g[90+i] for i in range(31)]

    #########################Fixed bit##########################
    for i in F:
        if i < 90:
            B[i] = 0
        else:
            S[i-90] = 0


    Rec = [g[i] for i in R]
    print("Recovered Bits are ", Rec)
    Fix = [g[i] for i in F]
    print("Fixed Bits are ", Fix)



    R_past = []
    L_rec = []
    cnt = 0
    flag = 1
    for i in range(keys):
        z = keystream(B,S)
        monom = list(z.monomials())
        t_var = list(z.variables())

        R_past = R_past + list(set(L_rec))
        m_rec = []
        for m in monom:
            m_var = list(m.variables())
            if (len(m_var) == 1) and (len(intersection(m_var,Rec)) > 0):
                L_rec = L_rec + m_var

            if (len(m_var) > 1) and (len(intersection(m_var,Rec)) > 0):
                m_rec = m_rec + [m]
        #print("monomials containing recovery bits (degree > 1) ",m_rec)

        for m in m_rec:
            m_var = list(m.variables())
            #Now L_rec contains current and past recovery bit in linear terms
            #Whereas R_past contains only the past recovery bit in linear terms
            if len(intersection(m_var,Rec)) > len(intersection(m_var,R_past)):
                f = open(filename,'a')
                f.write("\nError --- Future recovery bits found\n" + str(m))
                f.close()
                print("Error --- Future recovery bits found")
                print(m)

        L_rec = list(set(L_rec))
        if len(L_rec) != cnt + 1:
            flag = 0
        cnt = len(L_rec)
        print("Recovery bits till now in linear terms ",L_rec)

        B=NFSR2_fw_update(B,S[0])
        S=NFSR1_fw_update(S)

    f = open(filename,'a')
    if flag == 0:
        print("Failed")
        f.write("\nFailed\n")
    else:
        print("Passed")
        f.write("\nPassed\n")
        import csv
        with open(csv_file,'a') as f:
            writer = csv.writer(f)
            #writer.writerow(['Number of Recovered bits','Number of Fixed bits','Recovered bits','Fixed bits'])
            writer.writerow([len(R),len(F),Rec,Fix])
    f.close()
# Out:
# loop 1st part  0
# 1st part done
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-01-14
# 2nd part loop  0
# 2nd part done
# Keystream =  1
# status 2
# Recovery Bit  [b5]
# Fixed Bit  []
# Guessed Bit  [b0, b1, b2, b3, b4, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b31, b32, b33, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b44, b45, b46, b47, b48, b49, b50, b51, b52, b53, b54, b55, b56, b57, b58, b59, b60, b61, b62, b63, b64, b65, b66, b67, b68, b69, b70, b71, b72, b73, b74, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30]
# 1 0
# Length verified
# Gurobi Time =  0.008727550506591797
# Overall Time =  0.23978161811828613
# Recovered Bits are  [b5]
# Fixed Bits are  []
# Recovery bits till now in linear terms  [b5]
# Passed
# loop 1st part  0
# loop 1st part  1
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part done
# Keystream =  2
# status 2
# Recovery Bit  [b11, b46]
# Fixed Bit  []
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b31, b32, b33, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b44, b45, b47, b48, b49, b50, b51, b52, b53, b54, b55, b56, b57, b58, b59, b60, b61, b62, b63, b64, b65, b66, b67, b68, b69, b70, b71, b72, b73, b74, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30]
# 2 0
# Length verified
# Gurobi Time =  0.004476785659790039
# Overall Time =  0.17601633071899414
# Recovered Bits are  [b11, b46]
# Fixed Bits are  []
# Recovery bits till now in linear terms  [b11]
# Recovery bits till now in linear terms  [b46, b11]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part done
# Keystream =  3
# status 2
# Recovery Bit  [b5, b12, b56]
# Fixed Bit  []
# Guessed Bit  [b0, b1, b2, b3, b4, b6, b7, b8, b9, b10, b11, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b31, b32, b33, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b44, b45, b46, b47, b48, b49, b50, b51, b52, b53, b54, b55, b57, b58, b59, b60, b61, b62, b63, b64, b65, b66, b67, b68, b69, b70, b71, b72, b73, b74, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30]
# 3 0
# Length verified
# Gurobi Time =  0.002418041229248047
# Overall Time =  0.2557706832885742
# Recovered Bits are  [b5, b12, b56]
# Fixed Bits are  []
# Recovery bits till now in linear terms  [b5]
# Recovery bits till now in linear terms  [b5, b12]
# Recovery bits till now in linear terms  [b5, b12, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part done
# Keystream =  4
# status 2
# Recovery Bit  [b7, b12, b56, b74]
# Fixed Bit  [b68]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b8, b9, b10, b11, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b31, b32, b33, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b44, b45, b46, b47, b48, b49, b50, b51, b52, b53, b54, b55, b57, b58, b59, b60, b61, b62, b63, b64, b65, b66, b67, b69, b70, b71, b72, b73, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30]
# 4 1
# Length verified
# Gurobi Time =  0.012822866439819336
# Overall Time =  0.35446810722351074
# Recovered Bits are  [b7, b12, b56, b74]
# Fixed Bits are  [b68]
# Recovery bits till now in linear terms  [b7]
# Recovery bits till now in linear terms  [b7, b12]
# Recovery bits till now in linear terms  [b7, b12, b56]
# Recovery bits till now in linear terms  [b7, b74, b12, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part done
# Keystream =  5
# status 2
# Recovery Bit  [b31, b40, b56, b57, s27]
# Fixed Bit  [b66]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b32, b33, b34, b35, b36, b37, b38, b39, b41, b42, b43, b44, b45, b46, b47, b48, b49, b50, b51, b52, b53, b54, b55, b58, b59, b60, b61, b62, b63, b64, b65, b67, b68, b69, b70, b71, b72, b73, b74, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s28, s29, s30]
# 5 1
# Length verified
# Gurobi Time =  0.005661487579345703
# Overall Time =  0.4523615837097168
# Recovered Bits are  [b31, b40, b56, b57, s27]
# Fixed Bits are  [b66]
# Recovery bits till now in linear terms  [b40]
# Recovery bits till now in linear terms  [b31, b40]
# Recovery bits till now in linear terms  [b31, b56, b40]
# Recovery bits till now in linear terms  [b57, b31, b56, b40]
# Recovery bits till now in linear terms  [s27, b57, b31, b40, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part done
# Keystream =  6
# status 2
# Recovery Bit  [b7, b31, b56, b57, b59, s27]
# Fixed Bit  [b66, b68]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b32, b33, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b44, b45, b46, b47, b48, b49, b50, b51, b52, b53, b54, b55, b58, b60, b61, b62, b63, b64, b65, b67, b69, b70, b71, b72, b73, b74, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s28, s29, s30]
# 6 2
# Length verified
# Gurobi Time =  0.006999969482421875
# Overall Time =  0.5666654109954834
# Recovered Bits are  [b7, b31, b56, b57, b59, s27]
# Fixed Bits are  [b66, b68]
# Recovery bits till now in linear terms  [b7]
# Recovery bits till now in linear terms  [b7, b31]
# Recovery bits till now in linear terms  [b7, b31, b56]
# Recovery bits till now in linear terms  [b57, b7, b31, b56]
# Recovery bits till now in linear terms  [s27, b57, b31, b7, b56]
# Recovery bits till now in linear terms  [s27, b57, b31, b7, b59, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part done
# Keystream =  7
# status 2
# Recovery Bit  [b7, b46, b56, b58, b59, b74, s29]
# Fixed Bit  [b28, b68]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b29, b30, b31, b32, b33, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b44, b45, b47, b48, b49, b50, b51, b52, b53, b54, b55, b57, b60, b61, b62, b63, b64, b65, b66, b67, b69, b70, b71, b72, b73, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s30]
# 7 2
# Length verified
# Gurobi Time =  0.014381170272827148
# Overall Time =  0.6010105609893799
# Recovered Bits are  [b7, b46, b56, b58, b59, b74, s29]
# Fixed Bits are  [b28, b68]
# Recovery bits till now in linear terms  [b7]
# Recovery bits till now in linear terms  [b7, b46]
# Recovery bits till now in linear terms  [b7, b46, b56]
# Recovery bits till now in linear terms  [b7, b74, b46, b56]
# Recovery bits till now in linear terms  [b74, b7, b58, b46, b56]
# Recovery bits till now in linear terms  [b74, b7, b59, b58, b46, b56]
# Recovery bits till now in linear terms  [b74, s29, b7, b59, b58, b46, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# loop 1st part  7
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part loop  7
# 2nd part done
# Keystream =  8
# status 2
# Recovery Bit  [b31, b45, b56, b58, b59, b74, s29, s30]
# Fixed Bit  [b44, b68]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b32, b33, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b46, b47, b48, b49, b50, b51, b52, b53, b54, b55, b57, b60, b61, b62, b63, b64, b65, b66, b67, b69, b70, b71, b72, b73, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28]
# 8 2
# Length verified
# Gurobi Time =  0.014942169189453125
# Overall Time =  0.8183000087738037
# Recovered Bits are  [b31, b45, b56, b58, b59, b74, s29, s30]
# Fixed Bits are  [b44, b68]
# Recovery bits till now in linear terms  [b45]
# Recovery bits till now in linear terms  [b31, b45]
# Recovery bits till now in linear terms  [b56, b31, b45]
# Recovery bits till now in linear terms  [b74, b45, b31, b56]
# Recovery bits till now in linear terms  [b74, b45, b31, b58, b56]
# Recovery bits till now in linear terms  [b74, b45, b31, b59, b58, b56]
# Recovery bits till now in linear terms  [b74, b45, s29, b31, b59, b58, b56]
# Recovery bits till now in linear terms  [b74, b45, s29, b31, b59, b58, s30, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# loop 1st part  7
# loop 1st part  8
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part loop  7
# 2nd part loop  8
# 2nd part done
# Keystream =  9
# status 2
# Recovery Bit  [b12, b30, b33, b56, b58, b59, b62, s29, s30]
# Fixed Bit  [b44, b48, b68]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b31, b32, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b45, b46, b47, b49, b50, b51, b52, b53, b54, b55, b57, b60, b61, b63, b64, b65, b66, b67, b69, b70, b71, b72, b73, b74, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28]
# 9 3
# Length verified
# Gurobi Time =  0.030859947204589844
# Overall Time =  1.3102052211761475
# Recovered Bits are  [b12, b30, b33, b56, b58, b59, b62, s29, s30]
# Fixed Bits are  [b44, b48, b68]
# Recovery bits till now in linear terms  [b30]
# Recovery bits till now in linear terms  [b12, b30]
# Recovery bits till now in linear terms  [b56, b12, b30]
# Recovery bits till now in linear terms  [b30, b12, b33, b56]
# Recovery bits till now in linear terms  [b12, b33, b30, b58, b56]
# Recovery bits till now in linear terms  [b12, b33, b30, b59, b58, b56]
# Recovery bits till now in linear terms  [b12, s29, b33, b30, b59, b58, b56]
# Recovery bits till now in linear terms  [b12, s29, b33, b30, b59, b58, s30, b56]
# Recovery bits till now in linear terms  [b12, s29, b33, b30, b62, b59, b58, s30, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# loop 1st part  7
# loop 1st part  8
# loop 1st part  9
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part loop  7
# 2nd part loop  8
# 2nd part loop  9
# 2nd part done
# Keystream =  10
# status 2
# Recovery Bit  [b12, b30, b56, b58, b59, b62, b74, s1, s29, s30]
# Fixed Bit  [b17, b33, b38, b44, b68, b71]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b13, b14, b15, b16, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b31, b32, b34, b35, b36, b37, b39, b40, b41, b42, b43, b45, b46, b47, b48, b49, b50, b51, b52, b53, b54, b55, b57, b60, b61, b63, b64, b65, b66, b67, b69, b70, b72, b73, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28]
# 10 6
# Length verified
# Gurobi Time =  0.09662008285522461
# Overall Time =  1.9204003810882568
# Recovered Bits are  [b12, b30, b56, b58, b59, b62, b74, s1, s29, s30]
# Fixed Bits are  [b17, b33, b38, b44, b68, b71]
# Recovery bits till now in linear terms  [b30]
# Recovery bits till now in linear terms  [b12, b30]
# Recovery bits till now in linear terms  [b56, b12, b30]
# Recovery bits till now in linear terms  [b30, b74, b12, b56]
# Recovery bits till now in linear terms  [b74, b12, b30, b58, b56]
# Recovery bits till now in linear terms  [b74, b12, b30, b59, b58, b56]
# Recovery bits till now in linear terms  [b74, b12, s29, b30, b59, b58, b56]
# Recovery bits till now in linear terms  [b74, b12, s29, b30, b59, b58, s30, b56]
# Recovery bits till now in linear terms  [b74, b12, s29, b30, b62, b59, b58, s30, b56]
# Recovery bits till now in linear terms  [b74, s1, b12, s29, b30, b62, b59, b58, s30, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# loop 1st part  7
# loop 1st part  8
# loop 1st part  9
# loop 1st part  10
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part loop  7
# 2nd part loop  8
# 2nd part loop  9
# 2nd part loop  10
# 2nd part done
# Keystream =  11
# status 2
# Recovery Bit  [b12, b40, b51, b56, b58, b64, b76, s2, s3, s26, s30]
# Fixed Bit  [b39, b44, b50, b65, b70, b71, s16]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b31, b32, b33, b34, b35, b36, b37, b38, b41, b42, b43, b45, b46, b47, b48, b49, b52, b53, b54, b55, b57, b59, b60, b61, b62, b63, b66, b67, b68, b69, b72, b73, b74, b75, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s17, s18, s19, s20, s21, s22, s23, s24, s25, s27, s28, s29]
# 11 7
# Length verified
# Gurobi Time =  0.1668109893798828
# Overall Time =  2.3913111686706543
# Recovered Bits are  [b12, b40, b51, b56, b58, b64, b76, s2, s3, s26, s30]
# Fixed Bits are  [b39, b44, b50, b65, b70, b71, s16]
# Recovery bits till now in linear terms  [b40]
# Recovery bits till now in linear terms  [b12, b40]
# Recovery bits till now in linear terms  [b12, b56, b40]
# Recovery bits till now in linear terms  [s26, b12, b56, b40]
# Recovery bits till now in linear terms  [b12, s26, b40, b58, b56]
# Recovery bits till now in linear terms  [s26, b12, b76, b40, b58, b56]
# Recovery bits till now in linear terms  [b12, s26, b76, b51, b40, b58, b56]
# Recovery bits till now in linear terms  [s26, b12, b76, b51, b40, b58, s30, b56]
# Recovery bits till now in linear terms  [b12, s26, b76, b51, b40, b58, s2, s30, b56]
# Recovery bits till now in linear terms  [s26, b12, b76, b51, b40, b58, s2, s30, s3, b56]
# Recovery bits till now in linear terms  [b12, s26, b64, b76, b51, b40, b58, s2, s30, s3, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# loop 1st part  7
# loop 1st part  8
# loop 1st part  9
# loop 1st part  10
# loop 1st part  11
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part loop  7
# 2nd part loop  8
# 2nd part loop  9
# 2nd part loop  10
# 2nd part loop  11
# 2nd part done
# Keystream =  12
# status 2
# Recovery Bit  [b14, b16, b20, b54, b55, b56, b58, b60, b61, b64, b65, s2]
# Fixed Bit  [b22, b28, b32, b39, b50, b51, b70, b71, s3]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b15, b17, b18, b19, b21, b23, b24, b25, b26, b27, b29, b30, b31, b33, b34, b35, b36, b37, b38, b40, b41, b42, b43, b44, b45, b46, b47, b48, b49, b52, b53, b57, b59, b62, b63, b66, b67, b68, b69, b72, b73, b74, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30]
# 12 9
# Length verified
# Gurobi Time =  0.1916050910949707
# Overall Time =  3.5276882648468018
# Recovered Bits are  [b14, b16, b20, b54, b55, b56, b58, b60, b61, b64, b65, s2]
# Fixed Bits are  [b22, b28, b32, b39, b50, b51, b70, b71, s3]
# Recovery bits till now in linear terms  [b54]
# Recovery bits till now in linear terms  [b54, b55]
# Recovery bits till now in linear terms  [b54, b55, b56]
# Recovery bits till now in linear terms  [b54, b55, b56, b14]
# Recovery bits till now in linear terms  [b54, b14, b55, b58, b56]
# Recovery bits till now in linear terms  [b54, b14, b16, b55, b58, b56]
# Recovery bits till now in linear terms  [b60, b54, b16, b14, b55, b58, b56]
# Recovery bits till now in linear terms  [b60, b54, b14, b16, b55, b58, b61, b56]
# Recovery bits till now in linear terms  [b60, b54, b16, b14, b55, b58, s2, b61, b56]
# Recovery bits till now in linear terms  [b60, b54, b14, b16, b55, b20, b58, s2, b61, b56]
# Recovery bits till now in linear terms  [b60, b54, b64, b16, b14, b55, b20, b58, s2, b61, b56]
# Recovery bits till now in linear terms  [b60, b54, b64, b14, b16, b65, b55, b20, b58, s2, b61, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# loop 1st part  7
# loop 1st part  8
# loop 1st part  9
# loop 1st part  10
# loop 1st part  11
# loop 1st part  12
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part loop  7
# 2nd part loop  8
# 2nd part loop  9
# 2nd part loop  10
# 2nd part loop  11
# 2nd part loop  12
# 2nd part done
# Keystream =  13
# status 2
# Recovery Bit  [b12, b17, b35, b39, b56, b57, b58, b61, b64, b65, b66, b71, s2]
# Fixed Bit  [b20, b26, b29, b41, b51, b52, b68, b70, b75, b78, s3, s25]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b13, b14, b15, b16, b18, b19, b21, b22, b23, b24, b25, b27, b28, b30, b31, b32, b33, b34, b36, b37, b38, b40, b42, b43, b44, b45, b46, b47, b48, b49, b50, b53, b54, b55, b59, b60, b62, b63, b67, b69, b72, b73, b74, b76, b77, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s26, s27, s28, s29, s30]
# 13 12
# Length verified
# Gurobi Time =  0.2936732769012451
# Overall Time =  3.3666563034057617
# Recovered Bits are  [b12, b17, b35, b39, b56, b57, b58, b61, b64, b65, b66, b71, s2]
# Fixed Bits are  [b20, b26, b29, b41, b51, b52, b68, b70, b75, b78, s3, s25]
# Recovery bits till now in linear terms  [b71]
# Recovery bits till now in linear terms  [b71, b12]
# Recovery bits till now in linear terms  [b71, b12, b56]
# Recovery bits till now in linear terms  [b71, b57, b12, b56]
# Recovery bits till now in linear terms  [b71, b12, b57, b58, b56]
# Recovery bits till now in linear terms  [b71, b12, b57, b35, b58, b56]
# Recovery bits till now in linear terms  [b71, b12, b57, b35, b58, b17, b56]
# Recovery bits till now in linear terms  [b71, b12, b57, b35, b58, b17, b61, b56]
# Recovery bits till now in linear terms  [b71, b12, b57, b35, b58, s2, b17, b61, b56]
# Recovery bits till now in linear terms  [b71, b39, b12, b57, b35, b58, s2, b17, b61, b56]
# Recovery bits till now in linear terms  [b71, b39, b12, b64, b57, b35, b58, s2, b17, b61, b56]
# Recovery bits till now in linear terms  [b71, b39, b12, b64, b57, b35, b65, b58, s2, b17, b61, b56]
# Recovery bits till now in linear terms  [b71, b39, b12, b64, b57, b35, b65, b58, s2, b17, b61, b56, b66]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# loop 1st part  7
# loop 1st part  8
# loop 1st part  9
# loop 1st part  10
# loop 1st part  11
# loop 1st part  12
# loop 1st part  13
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part loop  7
# 2nd part loop  8
# 2nd part loop  9
# 2nd part loop  10
# 2nd part loop  11
# 2nd part loop  12
# 2nd part loop  13
# 2nd part done
# Keystream =  14
# status 2
# Recovery Bit  [b20, b23, b30, b46, b56, b57, b58, b60, b61, b64, b67, b82, s2, s28]
# Fixed Bit  [b6, b8, b17, b19, b22, b36, b39, b42, b43, b50, b53, b70, b73, b79]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b7, b9, b10, b11, b12, b13, b14, b15, b16, b18, b21, b24, b25, b26, b27, b28, b29, b31, b32, b33, b34, b35, b37, b38, b40, b41, b44, b45, b47, b48, b49, b51, b52, b54, b55, b59, b62, b63, b65, b66, b68, b69, b71, b72, b74, b75, b76, b77, b78, b80, b81, b83, b84, b85, b86, b87, b88, b89, s0, s1, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s29, s30]
# 14 14
# Length verified
# Gurobi Time =  0.3989832401275635
# Overall Time =  4.138954162597656
# Recovered Bits are  [b20, b23, b30, b46, b56, b57, b58, b60, b61, b64, b67, b82, s2, s28]
# Fixed Bits are  [b6, b8, b17, b19, b22, b36, b39, b42, b43, b50, b53, b70, b73, b79]
# Recovery bits till now in linear terms  [b30]
# Recovery bits till now in linear terms  [b46, b30]
# Recovery bits till now in linear terms  [b46, b56, b30]
# Recovery bits till now in linear terms  [b30, b46, b57, b56]
# Recovery bits till now in linear terms  [b57, b30, b58, b46, b56]
# Recovery bits till now in linear terms  [s28, b57, b30, b58, b46, b56]
# Recovery bits till now in linear terms  [b60, s28, b57, b30, b58, b46, b56]
# Recovery bits till now in linear terms  [b60, s28, b57, b30, b58, b46, b61, b56]
# Recovery bits till now in linear terms  [b60, s28, b57, b30, b58, s2, b46, b61, b56]
# Recovery bits till now in linear terms  [b60, s28, b57, b30, b20, b58, s2, b46, b61, b56]
# Recovery bits till now in linear terms  [b60, b64, s28, b57, b30, b20, b58, s2, b46, b61, b56]
# Recovery bits till now in linear terms  [b60, b64, s28, b57, b30, b82, b20, b58, s2, b46, b61, b56]
# Recovery bits till now in linear terms  [b60, b64, s28, b57, b23, b30, b82, b20, b58, s2, b46, b61, b56]
# Recovery bits till now in linear terms  [b60, b64, s28, b57, b23, b67, b30, b82, b20, b58, s2, b46, b61, b56]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# loop 1st part  7
# loop 1st part  8
# loop 1st part  9
# loop 1st part  10
# loop 1st part  11
# loop 1st part  12
# loop 1st part  13
# loop 1st part  14
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part loop  7
# 2nd part loop  8
# 2nd part loop  9
# 2nd part loop  10
# 2nd part loop  11
# 2nd part loop  12
# 2nd part loop  13
# 2nd part loop  14
# 2nd part done
# Keystream =  15
# status 2
# Recovery Bit  [b11, b39, b46, b56, b58, b61, b62, b64, b65, b66, b67, b68, s26, s28, s29]
# Fixed Bit  [b20, b29, b30, b31, b32, b33, b41, b42, b43, b72, b73, b74, b75, s2, s3]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b12, b13, b14, b15, b16, b17, b18, b19, b21, b22, b23, b24, b25, b26, b27, b28, b34, b35, b36, b37, b38, b40, b44, b45, b47, b48, b49, b50, b51, b52, b53, b54, b55, b57, b59, b60, b63, b69, b70, b71, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s27, s30]
# 15 15
# Length verified
# Gurobi Time =  0.5549905300140381
# Overall Time =  5.6030707359313965
# Recovered Bits are  [b11, b39, b46, b56, b58, b61, b62, b64, b65, b66, b67, b68, s26, s28, s29]
# Fixed Bits are  [b20, b29, b30, b31, b32, b33, b41, b42, b43, b72, b73, b74, b75, s2, s3]
# Recovery bits till now in linear terms  [b11]
# Recovery bits till now in linear terms  [b46, b11]
# Recovery bits till now in linear terms  [b46, b56, b11]
# Recovery bits till now in linear terms  [b46, s26, b11, b56]
# Recovery bits till now in linear terms  [s26, b11, b58, b46, b56]
# Recovery bits till now in linear terms  [s26, s28, b11, b58, b46, b56]
# Recovery bits till now in linear terms  [s26, s28, s29, b11, b58, b46, b56]
# Recovery bits till now in linear terms  [s26, s28, s29, b11, b58, b46, b61, b56]
# Recovery bits till now in linear terms  [s26, s28, s29, b11, b62, b58, b46, b61, b56]
# Recovery bits till now in linear terms  [b39, s26, s28, s29, b11, b62, b58, b46, b61, b56]
# Recovery bits till now in linear terms  [b39, s26, b64, s28, s29, b11, b62, b58, b46, b61, b56]
# Recovery bits till now in linear terms  [b39, b64, s26, s28, s29, b11, b62, b65, b58, b46, b61, b56]
# Recovery bits till now in linear terms  [b39, s26, b64, s28, s29, b11, b62, b65, b58, b46, b61, b56, b66]
# Recovery bits till now in linear terms  [b39, b64, s26, s28, s29, b67, b11, b62, b65, b58, b46, b61, b56, b66]
# Recovery bits till now in linear terms  [b39, s26, b64, s28, s29, b67, b11, b62, b68, b65, b58, b46, b61, b56, b66]
# Passed
# loop 1st part  0
# loop 1st part  1
# loop 1st part  2
# loop 1st part  3
# loop 1st part  4
# loop 1st part  5
# loop 1st part  6
# loop 1st part  7
# loop 1st part  8
# loop 1st part  9
# loop 1st part  10
# loop 1st part  11
# loop 1st part  12
# loop 1st part  13
# loop 1st part  14
# loop 1st part  15
# 1st part done
# 2nd part loop  0
# 2nd part loop  1
# 2nd part loop  2
# 2nd part loop  3
# 2nd part loop  4
# 2nd part loop  5
# 2nd part loop  6
# 2nd part loop  7
# 2nd part loop  8
# 2nd part loop  9
# 2nd part loop  10
# 2nd part loop  11
# 2nd part loop  12
# 2nd part loop  13
# 2nd part loop  14
# 2nd part loop  15
# 2nd part done
# Keystream =  16
# status 2
# Recovery Bit  [b46, b56, b58, b63, b64, b65, b66, b67, b68, b69, b71, s2, s26, s28, s29, s30]
# Fixed Bit  [b17, b30, b31, b34, b39, b40, b41, b42, b43, b44, b45, b53, b72, b73, b74, b75, s24]
# Guessed Bit  [b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b32, b33, b35, b36, b37, b38, b47, b48, b49, b50, b51, b52, b54, b55, b57, b59, b60, b61, b62, b70, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, s0, s1, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s25, s27]
# 16 17
# Length verified
# Gurobi Time =  0.5094842910766602
# Overall Time =  6.793548822402954
# Recovered Bits are  [b46, b56, b58, b63, b64, b65, b66, b67, b68, b69, b71, s2, s26, s28, s29, s30]
# Fixed Bits are  [b17, b30, b31, b34, b39, b40, b41, b42, b43, b44, b45, b53, b72, b73, b74, b75, s24]
# Recovery bits till now in linear terms  [b71]
# Recovery bits till now in linear terms  [b71, b46]
# Recovery bits till now in linear terms  [b71, b46, b56]
# Recovery bits till now in linear terms  [b71, b46, s26, b56]
# Recovery bits till now in linear terms  [b71, s26, b58, b46, b56]
# Recovery bits till now in linear terms  [b71, s26, s28, b58, b46, b56]
# Recovery bits till now in linear terms  [b71, s26, s28, s29, b58, b46, b56]
# Recovery bits till now in linear terms  [b71, s26, s28, s29, b58, b46, s30, b56]
# Recovery bits till now in linear terms  [b71, s26, s28, s29, b58, s2, b46, s30, b56]
# Recovery bits till now in linear terms  [b71, s26, s28, s29, b63, b58, s2, b46, s30, b56]
# Recovery bits till now in linear terms  [b71, s26, b64, s28, s29, b63, b58, s2, b46, s30, b56]
# Recovery bits till now in linear terms  [b71, s26, b64, s28, s29, b63, b65, b58, s2, b46, s30, b56]
# Recovery bits till now in linear terms  [b71, s26, b64, s28, s29, b63, b65, b58, s2, b46, s30, b56, b66]
# Recovery bits till now in linear terms  [b71, s26, b64, s28, s29, b67, b63, b65, b58, s2, b46, s30, b56, b66]
# Recovery bits till now in linear terms  [b71, s26, b64, s28, s29, b67, b63, b68, b65, b58, s2, b46, s30, b56, b66]

# %%
#keys = len(R)
R = [90+i for i in range(23,31,1)] + [92] +\
[i for i in range(63,70,1)]

F = [i for i in range(34,46,1)] + [i for i in range(72,82,1)]

B = [g[i] for i in range(90)]
S = [g[90+i] for i in range(31)]

keys = len(R)
#########################Fixed bit##########################
for i in F:
    if i < 90:
        B[i] = 0
    else:
        S[i-90] = 0

    
Rec = [g[i] for i in R]
print("Recovered Bits are ", Rec)
Fix = [g[i] for i in F]
print("Fixed Bits are ", Fix)



R_past = []
L_rec = []
cnt = 0
flag = 1
for i in range(keys):
    z = keystream(B,S)
    monom = list(z.monomials())
    t_var = list(z.variables())
    
    R_past = R_past + list(set(L_rec))
    m_rec = []
    for m in monom:
        m_var = list(m.variables())
        if len(intersection(m_var,Rec)) > 0:
            print(m,end=" + ")
        
    B=NFSR2_fw_update(B,S[0])
    S=NFSR1_fw_update(S)
    print('\n')
